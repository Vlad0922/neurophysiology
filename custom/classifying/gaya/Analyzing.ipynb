# %%
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
gaya_fast = pd.read_csv('gaya_500.csv')
gaya_fast.describe()
# Out:
#                 x           y  burst_index          cv          nu  \
# count  644.000000  644.000000   644.000000  644.000000  644.000000
# mean   184.191770   96.316460     0.326941    1.846121    0.761987
# std    103.621005   46.966374     0.669341    0.654150    0.689484
# min      5.700000    5.700000     0.000000    0.337286   -1.141021
# 25%     97.600000   63.200000     0.000000    1.407543    0.271799
# 50%    185.200000   89.000000     0.000000    1.790747    0.843717
# 75%    272.800000  120.600000     0.363636    2.214217    1.248157
# max    364.600000  241.200000     5.100000    4.830700    2.502079
#
#        freq_variance  modalirity_burst  pause_index  pause_ratio  \
# count     644.000000        644.000000   644.000000   644.000000
# mean       99.692270          0.814185     1.613099    10.560490
# std         1.415149          0.738142     3.780611    16.791309
# min        79.704657          0.000000     0.058824     0.482591
# ...

# %%
gaya_temp = pd.read_csv('gaya_temp.csv')
gaya_temp['temp'] = gaya_temp['temp'].astype(int)
gaya_temp.describe()
# Out:
#        burst_behavior  burst_index          cv  freq_variance    kurtosis  \
# count      837.000000        837.0  837.000000     837.000000  837.000000
# mean         0.000048          0.0    0.967365      96.831866   12.205942
# std          0.000706          0.0    0.387398       3.055335   11.846018
# min          0.000000          0.0    0.347033      75.128205    1.414702
# 25%          0.000000          0.0    0.773024      94.490358    3.882610
# 50%          0.000000          0.0    0.847465      98.034188    6.176202
# 75%          0.000000          0.0    1.078976      99.132948   18.055147
# max          0.016854          0.0    3.273293      99.975544   92.215231
#
#        modalirity_burst          nu  pause_index  pause_ratio    skewness  \
# count        837.000000  837.000000   837.000000   837.000000  837.000000
# mean           0.001154    0.940698     8.840108    41.686428    2.503191
# std            0.006637    0.287625    11.254977    53.610830    1.724865
# ...

# %% [markdown]
# ### Смотрим зависимости попарные
# Как-то плохо на данных от gaya делятся по температуре. Плохие данные? Плохие статистики?

# %%
sns.pairplot(gaya_temp.drop(['x', 'y', 'modalirity_burst', 'burst_index', 'burst_behavior'], axis=1), hue='temp')
